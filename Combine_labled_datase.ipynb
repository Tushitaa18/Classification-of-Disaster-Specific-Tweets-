# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
file_path = "/content/drive/MyDrive/2013_Pakistan_eq_CF_labeled_data.csv"
try:
    df_pak_Eq = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_California_Earthquake_CF_labeled_data.csv"
try:
    df_California = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_Chile_Earthquake_cl_labeled_data.csv"
try:
    df_Chile_Cl = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_Chile_Earthquake_en_CF_labeled_data.csv"
try:
    df_Chile_En = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_Hurricane_Odile_Mexico_en_CF_labeled_data.csv"
try:
    df_Mex = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")


    file_path = "/content/drive/MyDrive/2014_India_floods_CF_labeled_data.csv"
try:
    df_Ind = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_MERS_en_CF_labeled_data.csv"
try:
    df_mers = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_Pakistan_floods_CF_labeled_data.csv"
try:
    df_pak_floods = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_Philippines_Typhoon_Hagupit_en_CF_labeled_data.csv"
try:
    df_phil = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2014_ebola_CF_labeled_data.csv"
try:
    df_ebola = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2015_Cyclone_Pam_en_CF_labeled_data.csv"
try:
    df_pam = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")

    file_path = "/content/drive/MyDrive/2015_Nepal_Earthquake_en_CF_labeled_data.csv"
try:
    df_Nep = pd.read_csv(file_path)
    print("File loaded successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined
# An error occurred: name 'pd' is not defined

# %%
import pandas as pd

# Dictionary of file paths and variable names for your datasets in Google Drive
file_paths = {
    "df_cal_wildfires": "/content/drive/MyDrive/Projects/Summer25'/california-wildfires-final-data.csv",
    "df_harvey": "/content/drive/MyDrive/Projects/Summer25'/hurricane-harvey-final-data.csv",
    "df_irma": "/content/drive/MyDrive/Projects/Summer25'/hurricane-irma-final-data.csv",
    "df_maria": "/content/drive/MyDrive/Projects/Summer25'/hurricane-maria-final-data.csv",
    "df_iraq_iran_eq": "/content/drive/MyDrive/Projects/Summer25'/iraq-iran-earthquake-final-data.csv",
    "df_mexico_eq": "/content/drive/MyDrive/Projects/Summer25'/mexico-earthquake-final-data.csv",
    "df_srilanka_floods": "/content/drive/MyDrive/Projects/Summer25'/srilanka-floods-final-data.csv"
}

# Dictionary to store dataframes
dataframes = {}

# Load each file
for name, path in file_paths.items():
    try:
        df = pd.read_csv(path)
        dataframes[name] = df
        print(f"{name} loaded successfully. Shape: {df.shape}")
        print(df.head(), "\n")
    except Exception as e:
        print(f"Failed to load {name}: {e}\n")

# Example of how you can access one of the dataframes:
# print(dataframes["df_cal_wildfires"].head())
# Out:
# df_cal_wildfires loaded successfully. Shape: (1589, 15)
#              tweet_id              image_id    text_info  text_info_conf  \
# 0  917791044158185500  917791044158185473_0  informative          1.0000
# 1  917791130590183400  917791130590183424_0  informative          1.0000
# 2  917791291823591400  917791291823591425_0  informative          0.6813
# 3  917791291823591400  917791291823591425_1  informative          0.6813
# 4  917792092100988900  917792092100988929_0  informative          0.6727
#
#         image_info  image_info_conf                         text_human  \
# 0      informative           0.6766         other_relevant_information
# 1      informative           0.6667  infrastructure_and_utility_damage
# 2      informative           1.0000         other_relevant_information
# 3  not_informative           1.0000         other_relevant_information
# 4      informative           0.6612         other_relevant_information
#
# ...

# %%
# Add a 'source' column to each dataframe before combining
# Assuming 'dataframes' dictionary is already populated with your new datasets
# For example, if you ran the previous code snippet I provided to load them.

dataframes["df_cal_wildfires"]["source"] = "California_Wildfires"
dataframes["df_harvey"]["source"] = "Hurricane_Harvey"
dataframes["df_irma"]["source"] = "Hurricane_Irma"
dataframes["df_maria"]["source"] = "Hurricane_Maria"
dataframes["df_iraq_iran_eq"]["source"] = "Iraq_Iran_Earthquake"
dataframes["df_mexico_eq"]["source"] = "Mexico_Earthquake"
dataframes["df_srilanka_floods"]["source"] = "SriLanka_Floods"

# Combine all into a single dataframe
df = pd.concat(dataframes.values(), ignore_index=True)

# Print shape and sample
print("Combined shape:", df.shape)
print(df.head())
# Out:
# Combined shape: (18082, 16)
#              tweet_id              image_id    text_info  text_info_conf  \
# 0  917791044158185500  917791044158185473_0  informative          1.0000
# 1  917791130590183400  917791130590183424_0  informative          1.0000
# 2  917791291823591400  917791291823591425_0  informative          0.6813
# 3  917791291823591400  917791291823591425_1  informative          0.6813
# 4  917792092100988900  917792092100988929_0  informative          0.6727
#
#         image_info  image_info_conf                         text_human  \
# 0      informative           0.6766         other_relevant_information
# 1      informative           0.6667  infrastructure_and_utility_damage
# 2      informative           1.0000         other_relevant_information
# 3  not_informative           1.0000         other_relevant_information
# 4      informative           0.6612         other_relevant_information
#
# ...

# %%
# Step 1: Install required libraries
# !pip install transformers gensim --quiet
# !pip install numpy==1.26.0

# %%
# Step 1: NLTK Setup
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Step 3: Define Internet Idioms Dictionary
idioms_dict = {
    "ikr": "i know right",
    "hru": "how are you",
    "brb": "be right back",
    "lol": "laughing out loud",
    "omg": "oh my god",
    "idk": "i don't know",
    "smh": "shaking my head",
    "ttyl": "talk to you later",
    "imo": "in my opinion",
    "btw": "by the way",
    "tbh": "to be honest",
    "bday": "birthday",
    "thx": "thanks",
    "ty": "thank you",
    "plz": "please",
    "lmao": "laughing my ass off"
}

# %%
import re
import string
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

# Download NLTK resources
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Initialize tools
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Sample idioms dictionary
idioms_dict = {
    "idk": "i don't know",
    "brb": "be right back",
    "imo": "in my opinion",
    # Extend this dictionary
}

# Cleaning function
def clean_tweet(tweet):
    tweet = str(tweet).lower()
    tweet = re.sub(r"rt\s@\w+:?", "", tweet)  # Remove "RT @username:"
    tweet = re.sub(r"http\S+|www\S+", "", tweet)  # Remove URLs
    tweet = re.sub(r"@\w+", "", tweet)  # Remove mentions
    tweet = re.sub(f"[{re.escape(string.punctuation)}]", "", tweet)  # Remove punctuation
    tweet = re.sub(r"\d+", "", tweet)  # Remove digits

    words = re.findall(r'\b\w+\b', tweet)

    expanded_words = []
    for word in words:
        expanded = idioms_dict.get(word, word)
        expanded_words.extend(expanded.split())

    cleaned_words = [lemmatizer.lemmatize(w) for w in expanded_words if w not in stop_words]
    return ' '.join(cleaned_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Apply to DataFrame (assume df['tweet_text'] exists)
df['clean_text'] = df['tweet_text'].apply(clean_tweet)

# %%
# Step 2: Imports
import pandas as pd
import numpy as np
import re
import torch
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
df.to_csv('/content/drive/MyDrive/Adityacleaned_disaster_tweets.csv', index=False)

# %%
df.shape
# Out:
# (22099, 5)

# %%
df.head()
# Out:
#                tweet_id                                         tweet_text  \
# 0  '383600460340666369'  RT @Faiz_Baluch: #BalochistanEarthQuake Pakist...
# 1  '383790723222364161'  #Earthquake 2013-09-28 02:39:43 (M5.0) EAST OF...
# 2  '384232048124518400'  #earthquake M2.2: Puerto Rico region http://t....
# 3  '384860484643475456'  #PAKISTAN: #NASA releases images of Pakistan's...
# 4  '383407962619772928'  【#USGS #alert】 M 1.5, Central Alaska: Septembe...
#
#                       label                    source  \
# 0  other_useful_information  2013_Pakistan_Earthquake
# 1  other_useful_information  2013_Pakistan_Earthquake
# 2  other_useful_information  2013_Pakistan_Earthquake
# 3  other_useful_information  2013_Pakistan_Earthquake
# 4  other_useful_information  2013_Pakistan_Earthquake
#
#                                           clean_text
# 0  balochistanearthquake pakistan army terrorizin...
# 1    earthquake east south sandwich island fa notice
# ...
